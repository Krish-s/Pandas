# %% [markdown]
# <a href="https://colab.research.google.com/github/Krish-s/Pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df_store = pd.read_csv("/content/drive/MyDrive/Class notes/store sales dataset/stores_data_set.csv")
df_feature=pd.read_csv("/content/drive/MyDrive/Class notes/store sales dataset/Features_data_set.csv")
df_sales=pd.read_csv("/content/drive/MyDrive/Class notes/store sales dataset/sales_data_set.csv")

# %%
df_store
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
df_feature.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df_sales.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
pip install pandasai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 79.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.0 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["PANDASAI_API_KEY"]="$2a$10$XtC584efQne6aywU8lbWsOKYEJdZAvU/v3oKJjLsgsSBuVRrM/6.q"

# %%
df_store_sales = pd.merge(df_sales,df_store,on="Store")
df_feature.drop(columns ="IsHoliday",axis = 1,inplace = True)
df_final = pd.merge(df_store_sales,df_feature,on = ["Store","Date"])

# %%
df_final.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size  Temperature  \
# 0      1     1  05/02/2010      24924.50      False    A  151315        42.31
# 1      1     2  05/02/2010      50605.27      False    A  151315        42.31
# 2      1     3  05/02/2010      13740.12      False    A  151315        42.31
# 3      1     4  05/02/2010      39954.04      False    A  151315        42.31
# 4      1     5  05/02/2010      32229.38      False    A  151315        42.31
#
#    Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0       2.572        NaN        NaN        NaN        NaN        NaN
# 1       2.572        NaN        NaN        NaN        NaN        NaN
# 2       2.572        NaN        NaN        NaN        NaN        NaN
# 3       2.572        NaN        NaN        NaN        NaN        NaN
# 4       2.572        NaN        NaN        NaN        NaN        NaN
#
#           CPI  Unemployment
# 0  211.096358         8.106
# ...

# %%
from pandasai import SmartDataframe

# %%
sdf = SmartDataframe(df_final)

# %%
sdf.chat("return average Customer visit in type C store in april month")
# Out:
# <string>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
# 4166.0

# %%
print(sdf.last_code_generated)
# Out:
# df = pd.concat(dfs)
# df['Date'] = pd.to_datetime(df['Date'])
# df_filtered = df[(df['Date'].dt.month >= 1) & (df['Date'].dt.month <= 5)]
# result = df_filtered.groupby('Dept')['Weekly_Sales'].sum().reset_index()
# result_dict = {'type': 'dataframe', 'value': result}
# result_dict

# %% [markdown]
# ## task 1 To do solve the following questions ##

# %%
  TASK

1.)Identify average customer visit in Type C store in April Month.

2.)Find the highest sales in each store type on Holiday season.

3.)What is the expected sales of each depeartment when the unemployment factor is greater than 7.

4.)Aggregate net sales for each department in month wise.

5.)Identify the performance of the store on weekwise, without offers.

# %%
df_final["Date"]=pd.to_datetime(df_final["Date"],format = "%d/%m/%Y")

# %%
df_final["day"]=df_final["Date"].dt.day
df_final["month"]=df_final["Date"].dt.month
df_final["Year"]=df_final["Date"].dt.year
df_final["day_of_week"]=df_final["Date"].dt.day_of_week
df_final["week"] = df_final["Date"].dt.isocalendar().week

# %%
df_final
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1 2010-02-05      24924.50      False    A  151315
# 1           1     2 2010-02-05      50605.27      False    A  151315
# 2           1     3 2010-02-05      13740.12      False    A  151315
# 3           1     4 2010-02-05      39954.04      False    A  151315
# 4           1     5 2010-02-05      32229.38      False    A  151315
# ...       ...   ...        ...           ...        ...  ...     ...
# 421565     45    93 2012-10-26       2487.80      False    B  118221
# 421566     45    94 2012-10-26       5203.31      False    B  118221
# 421567     45    95 2012-10-26      56017.47      False    B  118221
# 421568     45    97 2012-10-26       6817.48      False    B  118221
# 421569     45    98 2012-10-26       1076.80      False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  ...  MarkDown3  MarkDown4  \
# ...

# %% [markdown]
# ## Task 2 to print ind vs aus match score card ##

# %%
train = pd.read_csv("/content/drive/MyDrive/Class notes/Datascience_dataset/train-chennai-sale.csv")

# %%
train
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1     P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
train.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE  \
# 0         1.0       3  AbNormal        Yes  15-05-1967  Commercial
# 1         1.0       5  AbNormal         No  22-12-1995  Commercial
# 2         1.0       3  AbNormal        Yes  09-02-1992  Commercial
# 3         2.0       5    Family         No  18-03-1988      Others
# 4         1.0       3  AbNormal        Yes  13-10-1979      Others
#
#   UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   object
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
train.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %%
train["AREA"].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar',
#        'KKNagar'], dtype=object)

# %%
train["AREA"] = train["AREA"].apply(lambda i: "Karapakkam" if (i== "Karapakam") else i)

# %%
train["AREA"].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Ana Nagar',
#        'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar', 'KKNagar'],
#       dtype=object)

# %%
train["AREA"]= train["AREA"].apply(lambda i : "Anna Nagar" if (i=="Ana Nagar") or (i=="Ann Nagar") else i)

# %%
train["AREA"].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Chormpet',
#        'Adyr', 'Velchery', 'KKNagar'], dtype=object)

# %%
train["AREA"]= train["AREA"].apply(lambda i : "Adyar" if (i=="Adyr")else i)
train["AREA"]= train["AREA"].apply(lambda i : "Chrompet" if (i=="Chrompt" or i=="Chrmpet" or i == "Chormpet")else i)
train["AREA"] = train["AREA"].apply(lambda i :"Velachery" if (i=="Velchery")else i)
train["AREA"]= train["AREA"].apply(lambda i : "KK Nagar" if (i=="KKNagar")else i)
train["AREA"]= train["AREA"].apply(lambda i : "T Nagar" if (i=="TNagar") else i)

# %%
train["AREA"].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'T Nagar'], dtype=object)

# %%
train["DATE_SALE"]=pd.to_datetime(train["DATE_SALE"],format = "%d-%m-%Y")
train["DATE_BUILD"] = pd.to_datetime(train["DATE_BUILD"],format ="%d-%m-%Y")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   datetime64[ns]
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   datetime64[ns]
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
train.set_index("PRT_ID",inplace = True)

# %%
train.head()
# Out:
#               AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210  Karapakkam      1004 2011-05-04            131        1.0         1.0
# P09411  Anna Nagar      1986 2006-12-19             26        2.0         1.0
# P01812       Adyar       909 2012-02-04             70        1.0         1.0
# P05346   Velachery      1855 2010-03-13             14        3.0         2.0
# P06210  Karapakkam      1226 2009-10-05             84        1.0         1.0
#
#         N_ROOM SALE_COND PARK_FACIL DATE_BUILD   BUILDTYPE UTILITY_AVAIL  \
# PRT_ID
# P03210       3  AbNormal        Yes 1967-05-15  Commercial        AllPub
# P09411       5  AbNormal         No 1995-12-22  Commercial        AllPub
# P01812       3  AbNormal        Yes 1992-02-09  Commercial           ELO
# P05346       5    Family         No 1988-03-18      Others       NoSewr
# P06210       3  AbNormal        Yes 1979-10-13      Others        AllPub
#
# ...

# %%
for i in train.select_dtypes(include = "object").columns
# Out:
#   File "<ipython-input-18-8d5d21cb15b9>", line 1
#     for i in train.select_dtypes(include = "object").columns
#                                                             ^
# SyntaxError: expected ':'

# %%
for i in train.select_dtypes(include = ["object"]).columns:
  print(i,train[i].unique())
# Out:
# AREA ['Karapakkam' 'Anna Nagar' 'Adyar' 'Velachery' 'Chrompet' 'KK Nagar'
#  'T Nagar']
# SALE_COND ['AbNormal' 'Family' 'Partial' 'AdjLand' 'Normal Sale' 'Ab Normal'
#  'Partiall' 'Adj Land' 'PartiaLl']
# PARK_FACIL ['Yes' 'No' 'Noo']
# BUILDTYPE ['Commercial' 'Others' 'Other' 'House' 'Comercial']
# UTILITY_AVAIL ['AllPub' 'ELO' 'NoSewr ' 'NoSeWa' 'All Pub']
# STREET ['Paved' 'Gravel' 'No Access' 'Pavd' 'NoAccess']
# MZZONE ['A' 'RH' 'RL' 'I' 'C' 'RM']

# %%
train["SALE_COND"] = train["SALE_COND"].apply(lambda i: "AbNormal" if (i=="Ab Normal")else i)
train["SALE_COND"] = train ["SALE_COND"].apply(lambda i : "Partial" if (i=="Partiall" or i =="PartiaLl")else i)
train["SALE_COND"] = train["SALE_COND"].apply(lambda i : "AdjLand" if (i=="Adj Land")else i)
train["PARK_FACIL"] = train["PARK_FACIL"].apply(lambda i : "No" if (i == "Noo") else i)
train["BUILDTYPE"]  = train["BUILDTYPE"].apply(lambda i : "Commercial" if (i=="Comercial")else i)
train["BUILDTYPE"] = train["BUILDTYPE"].apply(lambda i : "Other" if (i=="Others") else i)
train["UTILITY_AVAIL"] =train["UTILITY_AVAIL"].apply(lambda i: "AllPub" if (i=="All Pub")else i)
train["UTILITY_AVAIL"] = train["UTILITY_AVAIL"].apply(lambda i : "No Sewage" if (i=="NoSewr" or i=="NoSeWa" or i =="NoSewr ")else i)
train["STREET"] = train["STREET"].apply(lambda i: "Paved" if (i=="Pavd") else i)
train["STREET"] = train["STREET"].apply(lambda i : "No Access" if (i=="NoAccess")else i)

# %%
for i in train.select_dtypes(include=["object"]).columns :
  print(i,train[i].unique())
# Out:
# AREA ['Karapakkam' 'Anna Nagar' 'Adyar' 'Velachery' 'Chrompet' 'KK Nagar'
#  'T Nagar']
# SALE_COND ['AbNormal' 'Family' 'Partial' 'AdjLand' 'Normal Sale']
# PARK_FACIL ['Yes' 'No']
# BUILDTYPE ['Commercial' 'Other' 'House']
# UTILITY_AVAIL ['AllPub' 'ELO' 'No Sewage']
# STREET ['Paved' 'Gravel' 'No Access']
# MZZONE ['A' 'RH' 'RL' 'I' 'C' 'RM']

# %%
train1 = train.copy()

# %%
train["PARK_FACIL"]=train["PARK_FACIL"].replace({"Yes":1})

# %%
train
# Out:
#               AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210  Karapakkam      1004 2011-05-04            131        1.0         1.0
# P09411  Anna Nagar      1986 2006-12-19             26        2.0         1.0
# P01812       Adyar       909 2012-02-04             70        1.0         1.0
# P05346   Velachery      1855 2010-03-13             14        3.0         2.0
# P06210  Karapakkam      1226 2009-10-05             84        1.0         1.0
# ...            ...       ...        ...            ...        ...         ...
# P03834  Karapakkam       598 2011-01-03             51        1.0         1.0
# P10000   Velachery      1897 2004-04-08             52        3.0         2.0
# P09594   Velachery      1614 2006-08-25            152        2.0         1.0
# P06508  Karapakkam       787 2009-08-03             40        1.0         1.0
# P09794   Velachery      1896 2005-07-13            156        3.0         2.0
#
# ...

# %%
train = train1.copy()

# %%
train["PARK_FACIL"]=train["PARK_FACIL"].map({"Yes":1})

# %%
train
# Out:
#               AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210  Karapakkam      1004 2011-05-04            131        1.0         1.0
# P09411  Anna Nagar      1986 2006-12-19             26        2.0         1.0
# P01812       Adyar       909 2012-02-04             70        1.0         1.0
# P05346   Velachery      1855 2010-03-13             14        3.0         2.0
# P06210  Karapakkam      1226 2009-10-05             84        1.0         1.0
# ...            ...       ...        ...            ...        ...         ...
# P03834  Karapakkam       598 2011-01-03             51        1.0         1.0
# P10000   Velachery      1897 2004-04-08             52        3.0         2.0
# P09594   Velachery      1614 2006-08-25            152        2.0         1.0
# P06508  Karapakkam       787 2009-08-03             40        1.0         1.0
# P09794   Velachery      1896 2005-07-13            156        3.0         2.0
#
# ...

# %%
train=train1.copy()

# %%
train["PARK_FACIL"]=train["PARK_FACIL"].map({"Yes":1,"No":0})

# %%
train
# Out:
#               AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210  Karapakkam      1004 2011-05-04            131        1.0         1.0
# P09411  Anna Nagar      1986 2006-12-19             26        2.0         1.0
# P01812       Adyar       909 2012-02-04             70        1.0         1.0
# P05346   Velachery      1855 2010-03-13             14        3.0         2.0
# P06210  Karapakkam      1226 2009-10-05             84        1.0         1.0
# ...            ...       ...        ...            ...        ...         ...
# P03834  Karapakkam       598 2011-01-03             51        1.0         1.0
# P10000   Velachery      1897 2004-04-08             52        3.0         2.0
# P09594   Velachery      1614 2006-08-25            152        2.0         1.0
# P06508  Karapakkam       787 2009-08-03             40        1.0         1.0
# P09794   Velachery      1896 2005-07-13            156        3.0         2.0
#
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encode = OrdinalEncoder()

# %%
train["PARK_FACIL"]=encode.fit_transform(train[["PARK_FACIL"]])

# %%
train
# Out:
#               AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210  Karapakkam      1004 2011-05-04            131        1.0         1.0
# P09411  Anna Nagar      1986 2006-12-19             26        2.0         1.0
# P01812       Adyar       909 2012-02-04             70        1.0         1.0
# P05346   Velachery      1855 2010-03-13             14        3.0         2.0
# P06210  Karapakkam      1226 2009-10-05             84        1.0         1.0
# ...            ...       ...        ...            ...        ...         ...
# P03834  Karapakkam       598 2011-01-03             51        1.0         1.0
# P10000   Velachery      1897 2004-04-08             52        3.0         2.0
# P09594   Velachery      1614 2006-08-25            152        2.0         1.0
# P06508  Karapakkam       787 2009-08-03             40        1.0         1.0
# P09794   Velachery      1896 2005-07-13            156        3.0         2.0
#
# ...

# %%
for i in train.select_dtypes(include = ["object"]).columns:
  print(i,train[i].unique())
# Out:
# AREA ['Karapakkam' 'Anna Nagar' 'Adyar' 'Velachery' 'Chrompet' 'KK Nagar'
#  'T Nagar']
# SALE_COND ['AbNormal' 'Family' 'Partial' 'AdjLand' 'Normal Sale']
# BUILDTYPE ['Commercial' 'Other' 'House']
# UTILITY_AVAIL ['AllPub' 'ELO' 'No Sewage']
# STREET ['Paved' 'Gravel' 'No Access']
# MZZONE ['A' 'RH' 'RL' 'I' 'C' 'RM']

# %%
for i in train.select_dtypes(include=["object"]).columns:
  train[i]=encode.fit_transform(train[[i]])

# %%
for i in train.select_dtypes(include = ["object"]).columns:
  print(i,train[i].unique())

# %%
train
# Out:
#         AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210   4.0      1004 2011-05-04            131        1.0         1.0
# P09411   1.0      1986 2006-12-19             26        2.0         1.0
# P01812   0.0       909 2012-02-04             70        1.0         1.0
# P05346   6.0      1855 2010-03-13             14        3.0         2.0
# P06210   4.0      1226 2009-10-05             84        1.0         1.0
# ...      ...       ...        ...            ...        ...         ...
# P03834   4.0       598 2011-01-03             51        1.0         1.0
# P10000   6.0      1897 2004-04-08             52        3.0         2.0
# P09594   6.0      1614 2006-08-25            152        2.0         1.0
# P06508   4.0       787 2009-08-03             40        1.0         1.0
# P09794   6.0      1896 2005-07-13            156        3.0         2.0
#
#         N_ROOM  SALE_COND  PARK_FACIL DATE_BUILD  BUILDTYPE  UTILITY_AVAIL  \
# PRT_ID
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7109 entries, P03210 to P09794
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           7109 non-null   float64
#  1   INT_SQFT       7109 non-null   int64
#  2   DATE_SALE      7109 non-null   datetime64[ns]
#  3   DIST_MAINROAD  7109 non-null   int64
#  4   N_BEDROOM      7108 non-null   float64
#  5   N_BATHROOM     7104 non-null   float64
#  6   N_ROOM         7109 non-null   int64
#  7   SALE_COND      7109 non-null   float64
#  8   PARK_FACIL     7109 non-null   float64
#  9   DATE_BUILD     7109 non-null   datetime64[ns]
#  10  BUILDTYPE      7109 non-null   float64
#  11  UTILITY_AVAIL  7109 non-null   float64
#  12  STREET         7109 non-null   float64
#  13  MZZONE         7109 non-null   float64
#  14  QS_ROOMS       7109 non-null   float64
#  15  QS_BATHROOM    7109 non-null   float64
#  16  QS_BEDROOM     7109 non-null   float64
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/Class notes/Datascience_dataset/SAMPLE.csv")

# %%
df.isnull()
# Out:
#     sl No   name  college    hsc   SSLC  arrears  cmark
# 0    True   True     True   True   True     True   True
# 1   False  False    False  False  False    False  False
# 2   False  False    False  False  False    False   True
# 3   False  False    False   True  False    False  False
# 4   False  False    False  False  False    False  False
# 5   False  False     True  False  False    False  False
# 6   False  False    False  False  False    False  False
# 7   False  False    False  False   True    False  False
# 8   False  False    False  False  False    False  False
# 9   False  False    False  False  False    False  False
# 10  False  False    False   True  False    False  False
# 11   True   True     True   True   True     True   True
# 12   True   True     True   True   True     True   True
# 13  False  False    False  False  False    False  False
# 14  False  False    False  False  False     True  False
# 15  False  False    False  False  False    False  False
# ...

# %%
df.isnull().sum()
# Out:
# sl No      3
# name       3
# college    5
# hsc        5
# SSLC       5
# arrears    4
# cmark      4
# dtype: int64

# %%
df.notnull()
# Out:
#     sl No   name  college    hsc   SSLC  arrears  cmark
# 0   False  False    False  False  False    False  False
# 1    True   True     True   True   True     True   True
# 2    True   True     True   True   True     True  False
# 3    True   True     True  False   True     True   True
# 4    True   True     True   True   True     True   True
# 5    True   True    False   True   True     True   True
# 6    True   True     True   True   True     True   True
# 7    True   True     True   True  False     True   True
# 8    True   True     True   True   True     True   True
# 9    True   True     True   True   True     True   True
# 10   True   True     True  False   True     True   True
# 11  False  False    False  False  False    False  False
# 12  False  False    False  False  False    False  False
# 13   True   True     True   True   True     True   True
# 14   True   True     True   True   True    False   True
# 15   True   True     True   True   True     True   True
# ...

# %%
df.notnull().sum()
# Out:
# sl No      17
# name       17
# college    15
# hsc        15
# SSLC       15
# arrears    16
# cmark      16
# dtype: int64

# %%
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 11    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# ...

# %%
df.dropna()
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0

# %%
df.fillna(123)
# Out:
#     sl No name              college     hsc   SSLC  arrears  cmark
# 0   123.0  123                  123  123.00  123.0    123.0  123.0
# 1     1.0   A1                 IITM   89.90   92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY   76.80   77.9      3.0  123.0
# 3     3.0   A3      ANNA UNIVERSITY  123.00   85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY   92.50   94.6      1.0   76.0
# 5     5.0   A5                  123   79.30   65.0      2.0   89.0
# 6     6.0   A6                  SRM   99.80   88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA   91.80  123.0      7.0   78.3
# 8     8.0   A8             SAVEETHA   99.80   65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA   99.80   99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  123.00   85.6      6.0   99.0
# 11  123.0  123                  123  123.00  123.0    123.0  123.0
# 12  123.0  123                  123  123.00  123.0    123.0  123.0
# ...

# %%
df.fillna(method="bfill")
# Out:
# <ipython-input-47-6bd2f34f2c60>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   99.0
# 3     3.0   A3      ANNA UNIVERSITY  92.50  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  SRM  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  65.8      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# ...

# %%
df.bfill()
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   99.0
# 3     3.0   A3      ANNA UNIVERSITY  92.50  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  SRM  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  65.8      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  98.70  85.6      6.0   99.0
# 11    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 12    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# ...

# %%
df.fillna(method="ffill")
# Out:
# <ipython-input-49-5a0d178a1f3e>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   95.0
# 3     3.0   A3      ANNA UNIVERSITY  76.80  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5  ANAMALAI UNIVERSITY  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  88.1      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# ...

# %%
df.ffill()
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   95.0
# 3     3.0   A3      ANNA UNIVERSITY  76.80  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5  ANAMALAI UNIVERSITY  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  88.1      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  99.80  85.6      6.0   99.0
# 11    3.0   A3      ANNA UNIVERSITY  99.80  85.6      6.0   99.0
# 12    3.0   A3      ANNA UNIVERSITY  99.80  85.6      6.0   99.0
# ...

# %%
df.dropna(how="any")
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0

# %%
df.dropna(how="all")
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      NaN    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# ...

# %%
df.dropna(how="all",subset = ["college","hsc"])
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      NaN    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# ...

# %%
df1 = df.copy()

# %%
df.fillna(method = "bfill",inplace = True)
# Out:
# <ipython-input-70-8b054272d326>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "bfill",inplace = True)

# %%
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   99.0
# 3     3.0   A3      ANNA UNIVERSITY  92.50  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  SRM  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  65.8      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  98.70  85.6      6.0   99.0
# 11    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 12    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.duplicated(keep="first")
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.duplicated(keep="last")
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.duplicated(keep = False)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.drop_duplicates(keep="first")
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   99.0
# 3     3.0   A3      ANNA UNIVERSITY  92.50  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  SRM  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  65.8      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  98.70  85.6      6.0   99.0
# 11    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      1.0    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# ...

# %%
df.drop_duplicates(keep="first",subset = ["college","hsc"])
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   99.0
# 3     3.0   A3      ANNA UNIVERSITY  92.50  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  SRM  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  65.8      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  98.70  85.6      6.0   99.0
# 11    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      1.0    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# 16   12.0  A11            dhgvuicbh  88.20  84.9      2.0   72.0
# ...

# %%
df.drop_duplicates(keep= False,subset=["college"])
# Out:
#     sl No name college   hsc  SSLC  arrears  cmark
# 14   10.0   AD  fogjof  56.0   9.0      1.0    2.0

# %%
df["college"].duplicated(keep =False)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# Name: college, dtype: bool

# %%
df1
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 11    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# ...

# %%
df1.dropna(how = "all")
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      NaN    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# ...

# %%
df1["hsc"].fillna(df1["hsc"].mean())
# Out:
# 0     88.052667
# 1     89.900000
# 2     76.800000
# 3     88.052667
# 4     92.500000
# 5     79.300000
# 6     99.800000
# 7     91.800000
# 8     99.800000
# 9     99.800000
# 10    88.052667
# 11    88.052667
# 12    88.052667
# 13    98.700000
# 14    56.000000
# 15    94.000000
# 16    88.200000
# 17    78.900000
# 18    86.900000
# 19    88.390000
# Name: hsc, dtype: float64

# %%
for i in df1.select_dtypes(include =["float","int"]).columns:
  df1[i]=df[i].fillna(df1[[i]].mean())

# %%
df1
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     1.0  NaN                  NaN  89.90  92.6      0.0   95.0
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   99.0
# 3     3.0   A3      ANNA UNIVERSITY  92.50  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  65.8      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  98.70  85.6      6.0   99.0
# 11    9.0  NaN                  NaN  98.70  91.0      2.0   76.0
# 12    9.0  NaN                  NaN  98.70  91.0      2.0   76.0
# ...

# %%
train
# Out:
#         AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210   4.0      1004 2011-05-04            131        1.0         1.0
# P09411   1.0      1986 2006-12-19             26        2.0         1.0
# P01812   0.0       909 2012-02-04             70        1.0         1.0
# P05346   6.0      1855 2010-03-13             14        3.0         2.0
# P06210   4.0      1226 2009-10-05             84        1.0         1.0
# ...      ...       ...        ...            ...        ...         ...
# P03834   4.0       598 2011-01-03             51        1.0         1.0
# P10000   6.0      1897 2004-04-08             52        3.0         2.0
# P09594   6.0      1614 2006-08-25            152        2.0         1.0
# P06508   4.0       787 2009-08-03             40        1.0         1.0
# P09794   6.0      1896 2005-07-13            156        3.0         2.0
#
#         N_ROOM  SALE_COND  PARK_FACIL DATE_BUILD  BUILDTYPE  UTILITY_AVAIL  \
# PRT_ID
# ...

# %%
train.isnull().sum()
# Out:
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
train["N_BEDROOM"].unique()
# Out:
# array([ 1.,  2.,  3.,  4., nan])

# %%
train["N_BATHROOM"].unique()
# Out:
# array([ 1.,  2., nan])

# %%
val_col =["QS_ROOMS","QS_BATHROOM","QS_BEDROOM"]
target_col = "QS_OVERALL"

def target_quality_null(row):
  if pd.isnull(row[target_col]):
    return row[val_col].mean()
  else:
    return row[target_col]

# %%
train[target_col]=train.apply(target_quality_null,axis=1)

# %%
train.isnull().sum()
# Out:
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# DIST_MAINROAD    0
# N_BEDROOM        1
# N_BATHROOM       5
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64

# %%
train["N_BATHROOM"].unique()
# Out:
# array([ 1.,  2., nan])

# %%
train["N_BEDROOM"].unique()
# Out:
# array([ 1.,  2.,  3.,  4., nan])

# %%
train["N_ROOM"].unique()
# Out:
# array([3, 5, 4, 2, 6])

# %%
train["N_BEDROOM"].max()
# Out:
# 4.0

# %%
bed ="N_BEDROOM"
bath = "N_BATHROOM"
room = "N_ROOM"

def missing_bath_rooms(row):
  if pd.isnull(row[bath]):
    if row[room]> 4:
      return train[bath].max()
    else:
      return train[bath].min()
  else:
      return row[bath]

def missing_bed_rooms(row):
  if pd.isnull(row[bed]):
    if row[room] > 4:
      return train[bed].max()
    else:
      return train[bed].min()
  else:
    return row[bed]

# %%
train["N_BEDROOM"] = train.apply(missing_bed_rooms,axis=1)

# %%
train["N_BEDROOM"].unique()
# Out:
# array([1., 2., 3., 4.])

# %%
train["N_BATHROOM"]= train.apply(missing_bath_rooms,axis=1)

# %%
train["N_BATHROOM"].unique()
# Out:
# array([1., 2.])

# %%
train.isnull().sum()
# Out:
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# N_BATHROOMS      0
# dtype: int64

# %%
pd.set_option("display.max_columns",None)

# %%
train.head()
# Out:
#         AREA  INT_SQFT  DATE_SALE  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# PRT_ID
# P03210   4.0      1004 2011-05-04            131        1.0         1.0
# P09411   1.0      1986 2006-12-19             26        2.0         1.0
# P01812   0.0       909 2012-02-04             70        1.0         1.0
# P05346   6.0      1855 2010-03-13             14        3.0         2.0
# P06210   4.0      1226 2009-10-05             84        1.0         1.0
#
#         N_ROOM  SALE_COND  PARK_FACIL DATE_BUILD  BUILDTYPE  UTILITY_AVAIL  \
# PRT_ID
# P03210       3        0.0         1.0 1967-05-15        0.0            0.0
# P09411       5        0.0         0.0 1995-12-22        0.0            0.0
# P01812       3        0.0         1.0 1992-02-09        0.0            1.0
# P05346       5        2.0         0.0 1988-03-18        2.0            2.0
# P06210       3        0.0         1.0 1979-10-13        2.0            0.0
#
# ...

# %%
train2 = train.copy()

# %%
train3 = train.copy()
